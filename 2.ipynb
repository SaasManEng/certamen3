# %%
vendedor =[
 [35.000, 45.000, 55.000],
 [36.000, 48.000, 58.000],
 [37.000, 48.000, 59.000]

]

for i, persona in enumerate(persona): 
    promedio = sum(persona) / len(persona)
    print(f"persona"{i+1}: {persona}")
